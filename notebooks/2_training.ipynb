# %% [markdown]
# # Model Training
#
# In this notebook, we'll train a LightGBM model using Amazon SageMaker, so
# we have an example trained model to explain.
#
# You can bring also bring your own trained models to explain. See the
# customizing section for more details.
#
# **Note**: When running this notebook on SageMaker Studio, you should make
# sure the 'SageMaker JumpStart Data Science 1.0' image/kernel is used. You
# can run all cells or step through them one at a time.
#
# <p align="center">
#   <img src="https://github.com/awslabs/sagemaker-explaining-credit-decisions/raw/master/docs/architecture_diagrams/stage_2.png" width="1000px">
# </p>

# %% [markdown]
# We then import a variety of packages that will be used throughout
# the notebook. One of the most important packages used throughout this
# solution is the Amazon SageMaker Python SDK (i.e. `import sagemaker`). We
# also import modules from our own custom package that can be found at
# `./package`.

# %%
from pathlib import Path
from sagemaker.sklearn import SKLearn
import shutil
import sys

sys.path.insert(0, '../package')
from package import config, utils
from package.sagemaker import containers

# %% [markdown]
# ## Container
# We now build our custom Docker image that will be used for model training
# and deployment. It extends the official Amazon SageMaker framework image
# for Scikit-learn, by adding additional packages such as
# [LightGBM](https://lightgbm.readthedocs.io/en/latest/) and
# [SHAP](https://github.com/slundberg/shap). After building the image, we
# upload it to our solution's Amazon ECR repository.

# %%
# !rm -f ../containers/model.zip

# %%
shutil.make_archive('../containers/model', 'zip', '../containers/model/')
# Out:
# '/home/sagemaker-user/S3Downloads/jumpstart-prod-ecd_51p2dp/containers/model.zip'

# %%
# !aws s3 cp ../containers/model.zip s3://$config.S3_BUCKET/containers/model.zip --quiet

# %%
containers.build(project_name=config.CODE_BUILD_PROJECT)
# Out:
# Starting a build job for CodeBuild project: sagemaker-soln-ecd-js-51p2dp-container-build
# ...[Container] 2021/09/29 05:45:12 Waiting for agent ping
#
# [Container] 2021/09/29 05:45:15 Waiting for DOWNLOAD_SOURCE
# [Container] 2021/09/29 05:45:16 Phase is DOWNLOAD_SOURCE
# [Container] 2021/09/29 05:45:16 CODEBUILD_SRC_DIR=/codebuild/output/src229047242/src
# [Container] 2021/09/29 05:45:16 YAML location is /codebuild/output/src229047242/src/buildspec.yaml
# [Container] 2021/09/29 05:45:16 Processing environment variables
# [Container] 2021/09/29 05:45:16 Selecting 'python' runtime version '3.8' based on manual selections...
# [Container] 2021/09/29 05:45:16 Running command echo "Installing Python version 3.8 ..."
# Installing Python version 3.8 ...
#
# [Container] 2021/09/29 05:45:16 Running command pyenv global  $PYTHON_38_VERSION
#
# [Container] 2021/09/29 05:45:16 Moving to directory /codebuild/output/src229047242/src
# [Container] 2021/09/29 05:45:16 Registering with agent
# [Container] 2021/09/29 05:45:16 Phases found in YAML: 2
# [Container] 2021/09/29 05:45:16  INSTALL: 1 commands
# [Container] 2021/09/29 05:45:16  BUILD: 3 commands
# [Container] 2021/09/29 05:45:16 Phase complete: DOWNLOAD_SOURCE State: SUCCEEDED
# [Container] 2021/09/29 05:45:16 Phase context status code:  Message:
# [Container] 2021/09/29 05:45:16 Entering phase INSTALL
# [Container] 2021/09/29 05:45:16 Running command pip install sagemaker==1.55.4
# Collecting sagemaker==1.55.4
#   Downloading sagemaker-1.55.4.tar.gz (302 kB)
# Requirement already satisfied: boto3>=1.10.44 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from sagemaker==1.55.4) (1.18.6)
# Collecting numpy>=1.9.0
#   Downloading numpy-1.21.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.8 MB)
# Collecting protobuf>=3.1
#   Downloading protobuf-3.18.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting scipy>=0.19.0
#   Downloading scipy-1.7.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
# Collecting protobuf3-to-dict>=0.1.5
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting smdebug-rulesconfig==0.1.2
#   Downloading smdebug_rulesconfig-0.1.2-py2.py3-none-any.whl (10 kB)
# Collecting importlib-metadata>=1.4.0
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting packaging>=20.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from boto3>=1.10.44->sagemaker==1.55.4) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.6 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from boto3>=1.10.44->sagemaker==1.55.4) (1.21.6)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from boto3>=1.10.44->sagemaker==1.55.4) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from botocore<1.22.0,>=1.21.6->boto3>=1.10.44->sagemaker==1.55.4) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from botocore<1.22.0,>=1.21.6->boto3>=1.10.44->sagemaker==1.55.4) (1.26.6)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.1-py3-none-any.whl (5.3 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: six in /root/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from protobuf3-to-dict>=0.1.5->sagemaker==1.55.4) (1.16.0)
# Building wheels for collected packages: sagemaker, protobuf3-to-dict
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-1.55.4-py2.py3-none-any.whl size=398980 sha256=7e2b83300c370c9f09c5bc386f28b44b9b74912a55052a43c1e7d0965d9467aa
#   Stored in directory: /root/.cache/pip/wheels/04/5e/ab/37af494ebcc98973057aaf24b80f73f8ee1b81f36ee5b88d75
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4029 sha256=6ab83ff8b0ee1b2a9458f099bbf7b556b4145c1606ba663b4112f3475c759313
#   Stored in directory: /root/.cache/pip/wheels/fc/10/27/2d1e23d8b9a9013a83fbb418a0b17b1e6f81c8db8f53b53934
# Successfully built sagemaker protobuf3-to-dict
# Installing collected packages: zipp, pyparsing, protobuf, numpy, smdebug-rulesconfig, scipy, protobuf3-to-dict, packaging, importlib-metadata, sagemaker
# Successfully installed importlib-metadata-4.8.1 numpy-1.21.2 packaging-21.0 protobuf-3.18.0 protobuf3-to-dict-0.1.5 pyparsing-2.4.7 sagemaker-1.55.4 scipy-1.7.1 smdebug-rulesconfig-0.1.2 zipp-3.5.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/root/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.
#
# [Container] 2021/09/29 05:45:33 Phase complete: INSTALL State: SUCCEEDED
# [Container] 2021/09/29 05:45:33 Phase context status code:  Message:
# [Container] 2021/09/29 05:45:33 Entering phase PRE_BUILD
# [Container] 2021/09/29 05:45:33 Phase complete: PRE_BUILD State: SUCCEEDED
# [Container] 2021/09/29 05:45:33 Phase context status code:  Message:
# [Container] 2021/09/29 05:45:33 Entering phase BUILD
# [Container] 2021/09/29 05:45:33 Running command echo Started $ECR_IMAGE build at `date`.
# Started 396548483691.dkr.ecr.us-east-1.amazonaws.com/sagemaker-soln-ecd-js-51p2dp:latest build at Wed Sep 29 05:45:33 UTC 2021.
#
# [Container] 2021/09/29 05:45:33 Running command SM_ACCOUNT=$(python ./src/get_sm_account.py --region $AWS_REGION --framework scikit-learn)
# $(aws ecr get-login --region $AWS_REGION --registry-ids $AWS_ACCOUNT --no-include-email)
# $(aws ecr get-login --region $AWS_REGION --registry-ids $SM_ACCOUNT --no-include-email)
# SCIKIT_LEARN_IMAGE=$SM_ACCOUNT.dkr.ecr.$AWS_REGION.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3
# docker build -t $ECR_REPOSITORY --build-arg SCIKIT_LEARN_IMAGE=$SCIKIT_LEARN_IMAGE .
# docker tag $ECR_REPOSITORY $ECR_IMAGE
# docker push $ECR_IMAGE
#
# WARNING:root:pandas failed to import. Analytics features will be impaired or broken.
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon  26.11kB
# Step 1/4 : ARG SCIKIT_LEARN_IMAGE
# Step 2/4 : FROM $SCIKIT_LEARN_IMAGE
# 0.20.0-cpu-py3: Pulling from sagemaker-scikit-learn
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 3b244d223c24: Pulling fs layer
# 5c7d5e4a2395: Pulling fs layer
# 15ffc7405963: Pulling fs layer
# d0375a1483b6: Pulling fs layer
# 854ce0d7bfac: Pulling fs layer
# b09c2a9c124b: Pulling fs layer
# 061ef6891127: Pulling fs layer
# 1149b21fbf19: Pulling fs layer
# b09c2a9c124b: Waiting
# 15ffc7405963: Waiting
# 061ef6891127: Waiting
# 4c6ec688ebe3: Waiting
# 1149b21fbf19: Waiting
# 3b244d223c24: Waiting
# 5c7d5e4a2395: Waiting
# d0375a1483b6: Waiting
# 854ce0d7bfac: Waiting
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 3b244d223c24: Verifying Checksum
# 3b244d223c24: Download complete
# 5c7d5e4a2395: Verifying Checksum
# 5c7d5e4a2395: Download complete
# 854ce0d7bfac: Verifying Checksum
# 854ce0d7bfac: Download complete
# d0375a1483b6: Verifying Checksum
# d0375a1483b6: Download complete
# 061ef6891127: Verifying Checksum
# 061ef6891127: Download complete
# 1149b21fbf19: Verifying Checksum
# 1149b21fbf19: Download complete
# b09c2a9c124b: Verifying Checksum
# b09c2a9c124b: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 15ffc7405963: Verifying Checksum
# 15ffc7405963: Download complete
# 3b244d223c24: Pull complete
# 5c7d5e4a2395: Pull complete
# 15ffc7405963: Pull complete
# d0375a1483b6: Pull complete
# 854ce0d7bfac: Pull complete
# b09c2a9c124b: Pull complete
# 061ef6891127: Pull complete
# 1149b21fbf19: Pull complete
# Digest: sha256:0924c8fff44441d5dab74fc8ff7c5ecbc94af2215a4581e3302f850275bb900b
# Status: Downloaded newer image for 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3
#  ---> 6c10beb91746
# Step 3/4 : COPY requirements.txt /requirements.txt
#  ---> d5864b42db50
# Step 4/4 : RUN pip install --no-cache -r /requirements.txt &&     rm /requirements.txt
#  ---> Running in 95fca2e56104
# Collecting attrs==19.3.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting bokeh==2.0.1
#   Downloading bokeh-2.0.1.tar.gz (8.6 MB)
# Collecting boto3==1.12.41
#   Downloading boto3-1.12.41-py2.py3-none-any.whl (128 kB)
# Collecting botocore==1.15.41
#   Downloading botocore-1.15.41-py2.py3-none-any.whl (6.1 MB)
# Collecting certifi==2020.4.5.1
#   Downloading certifi-2020.4.5.1-py2.py3-none-any.whl (157 kB)
# Collecting chardet==3.0.4
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting docker==4.2.0
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting docutils==0.15.2
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
# Collecting idna==2.9
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata==1.6.0
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting jinja2==2.11.2
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting jmespath==0.9.5
#   Downloading jmespath-0.9.5-py2.py3-none-any.whl (24 kB)
# Collecting joblib==0.14.1
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
# Requirement already satisfied: markupsafe==1.1.1 in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 62)) (1.1.1)
# Requirement already satisfied: numpy==1.20.1 in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 66)) (1.20.1)
# Collecting packaging==20.3
#   Downloading packaging-20.3-py2.py3-none-any.whl (37 kB)
# Collecting pandas==1.0.3
#   Downloading pandas-1.0.3-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
# Collecting pillow==7.1.1
#   Downloading Pillow-7.1.1-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Collecting protobuf3-to-dict==0.1.5
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting protobuf==3.11.3
#   Downloading protobuf-3.11.3-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pyrsistent==0.16.0
#   Downloading pyrsistent-0.16.0.tar.gz (108 kB)
# Requirement already satisfied: python-dateutil==2.8.1 in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 106)) (2.8.1)
# Collecting pytz==2020.1
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting pyyaml==5.3.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
# Collecting requests==2.23.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting s3transfer==0.3.3
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting sagemaker==1.55.4
#   Downloading sagemaker-1.55.4.tar.gz (302 kB)
# Collecting scikit-learn==0.22.2.post1
#   Downloading scikit_learn-0.22.2.post1-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
# Collecting shap==0.35.0
#   Downloading shap-0.35.0.tar.gz (273 kB)
# Collecting six==1.14.0
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Collecting smdebug-rulesconfig==0.1.2
#   Downloading smdebug_rulesconfig-0.1.2-py2.py3-none-any.whl (10 kB)
# Collecting tornado==5.1.1
#   Downloading tornado-5.1.1.tar.gz (516 kB)
# Collecting tqdm==4.45.0
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
# Collecting typing-extensions==3.7.4.2
#   Downloading typing_extensions-3.7.4.2-py3-none-any.whl (22 kB)
# Collecting urllib3==1.25.9
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting websocket-client==0.57.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting zipp==3.1.0
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.7/site-packages (from jsonschema==3.2.0->-r /requirements.txt (line 58)) (52.0.0.post20210125)
# Building wheels for collected packages: bokeh, protobuf3-to-dict, pyrsistent, pyyaml, sagemaker, shap, tornado
#   Building wheel for bokeh (setup.py): started
#   Building wheel for bokeh (setup.py): finished with status 'done'
#   Created wheel for bokeh: filename=bokeh-2.0.1-py3-none-any.whl size=9080029 sha256=f1cf1bf48506aaa65725a9e439a0d84b34527c39240a7b55a987a29debc926ee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/9f/9e/ac/f24f30e119df73511fde9af8aa747217ac8824e662037ba9a8
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4030 sha256=8bcefa5acbe1c3d524a4d2233ddf5fe7ae2696cb912e8ebb96ad130ee5658fd6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/ce/a0/8b/995ce2fbaf0e9fe7eb91da84e99e84d1b35cfaa555f2b8f1c7
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.16.0-cp37-cp37m-linux_x86_64.whl size=114464 sha256=a8a7f1184b842aeb5c7c992a7e11e0ca31323f3ba27445f756a18376f6f2009c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/22/52/11/f0920f95c23ed7d2d0b05f2b7b2f4509e87a20cfe8ea43d987
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=e0f6bba46f0deb5e194c7994088f41a860f49d9b5929e20d09b6fdc0264ecabc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-1.55.4-py2.py3-none-any.whl size=398962 sha256=f19c613876cf4ebb8349aade13302346ca7e32b4f6280e4ed19b7a2873bfb64b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/ad/11/45/04c0af6facb212952378482002c1000eba3a2cc00c22300bb9
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.35.0-cp37-cp37m-linux_x86_64.whl size=399561 sha256=6500df8becdee941be9861970b37b1525bc446af638d65d8cfb6a905cb54e96f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/c3/e0/82/26cebc699e23c6a1b9963981e1a10ed7de75db012f4af12428
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-5.1.1-cp37-cp37m-linux_x86_64.whl size=457704 sha256=64bca0e26b0bbe95d4553f96ce4544215622011159e741a117adb3b0f510a6e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7ydmmrf/wheels/83/91/4b/ee8ffb993d3372fc4129c52c9140792c118dda0373b41e7a8f
# Successfully built bokeh protobuf3-to-dict pyrsistent pyyaml sagemaker shap tornado
# Installing collected packages: six, urllib3, jmespath, docutils, botocore, zipp, scipy, s3transfer, pytz, pyparsing, protobuf, joblib, idna, chardet, certifi, websocket-client, typing-extensions, tqdm, tornado, smdebug-rulesconfig, scikit-learn, requests, pyyaml, pyrsistent, protobuf3-to-dict, pillow, pandas, packaging, jinja2, importlib-metadata, boto3, attrs, shap, sagemaker, lightgbm, jsonschema, docker, bokeh
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.4
#     Uninstalling urllib3-1.26.4:
#       Successfully uninstalled urllib3-1.26.4
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 0.10.0
#     Uninstalling jmespath-0.10.0:
#       Successfully uninstalled jmespath-0.10.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.20.36
#     Uninstalling botocore-1.20.36:
#       Successfully uninstalled botocore-1.20.36
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.2
#     Uninstalling scipy-1.6.2:
#       Successfully uninstalled scipy-1.6.2
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.3.6
#     Uninstalling s3transfer-0.3.6:
#       Successfully uninstalled s3transfer-0.3.6
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.1
#     Uninstalling pytz-2021.1:
#       Successfully uninstalled pytz-2021.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.15.6
#     Uninstalling protobuf-3.15.6:
#       Successfully uninstalled protobuf-3.15.6
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.6.20
#     Uninstalling certifi-2020.6.20:
#       Successfully uninstalled certifi-2020.6.20
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.20.0
#     Uninstalling scikit-learn-0.20.0:
#       Successfully uninstalled scikit-learn-0.20.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.17.36
#     Uninstalling boto3-1.17.36:
#       Successfully uninstalled boto3-1.17.36
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 4.9.2 requires ruamel_yaml>=0.11.14, which is not installed.
# sagemaker-sklearn-container 1.0 requires pandas==0.25.*, but you have pandas 1.0.3 which is incompatible.
# Successfully installed attrs-19.3.0 bokeh-2.0.1 boto3-1.12.41 botocore-1.15.41 certifi-2020.4.5.1 chardet-3.0.4 docker-4.2.0 docutils-0.15.2 idna-2.9 importlib-metadata-1.6.0 jinja2-2.11.2 jmespath-0.9.5 joblib-0.14.1 jsonschema-3.2.0 lightgbm-2.3.1 packaging-20.3 pandas-1.0.3 pillow-7.1.1 protobuf-3.11.3 protobuf3-to-dict-0.1.5 pyparsing-2.4.7 pyrsistent-0.16.0 pytz-2020.1 pyyaml-5.3.1 requests-2.23.0 s3transfer-0.3.3 sagemaker-1.55.4 scikit-learn-0.22.2.post1 scipy-1.5.2 shap-0.35.0 six-1.14.0 smdebug-rulesconfig-0.1.2 tornado-5.1.1 tqdm-4.45.0 typing-extensions-3.7.4.2 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
# Removing intermediate container 95fca2e56104
#  ---> 2f245e3caf77
# Successfully built 2f245e3caf77
# Successfully tagged sagemaker-soln-ecd-js-51p2dp:latest
# The push refers to repository [396548483691.dkr.ecr.us-east-1.amazonaws.com/sagemaker-soln-ecd-js-51p2dp]
# f4d4a6cb8d22: Preparing
# 158fbed1816b: Preparing
# 60f01a26d0f9: Preparing
# 5de3df204d60: Preparing
# 9333a112a1f9: Preparing
# cd6c205eb8a5: Preparing
# cf329e8799af: Preparing
# ba8b08320039: Preparing
# 59ac78afdd7d: Preparing
# 6e2768fe446b: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# ba8b08320039: Waiting
# 59ac78afdd7d: Waiting
# 6e2768fe446b: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# cd6c205eb8a5: Waiting
# cf329e8799af: Waiting
# 158fbed1816b: Pushed
# 5de3df204d60: Pushed
# 60f01a26d0f9: Pushed
# cd6c205eb8a5: Pushed
# 9333a112a1f9: Pushed
# cf329e8799af: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# f4d4a6cb8d22: Pushed
# 59ac78afdd7d: Pushed
# 935c56d8b3f9: Pushed
# 6e2768fe446b: Pushed
#
# ba8b08320039: Pushed
# latest: digest: sha256:776d0311d06bbb81039ef7865dbe802563b90b85493c48f43d56c682dcfae4c0 size: 3255
#
# [Container] 2021/09/29 05:48:15 Running command echo Completed $ECR_IMAGE build at `date`.
# Completed 396548483691.dkr.ecr.us-east-1.amazonaws.com/sagemaker-soln-ecd-js-51p2dp:latest build at Wed Sep 29 05:48:15 UTC 2021.
#
# [Container] 2021/09/29 05:48:15 Phase complete: BUILD State: SUCCEEDED
# [Container] 2021/09/29 05:48:15 Phase context status code:  Message:
# [Container] 2021/09/29 05:48:15 Entering phase POST_BUILD
# [Container] 2021/09/29 05:48:15 Phase complete: POST_BUILD State: SUCCEEDED
# [Container] 2021/09/29 05:48:15 Phase context status code:  Message:

# %% [markdown]
# ## Model Training
# Amazon SageMaker provides two methods for training and deploying models.
# You can start by quickly testing and debuging models on the Amazon
# SageMaker Notebook instance using local mode. After this, you can scale
# up training with SageMaker mode on dedicated instances and deploy the
# model on dedicated instance too. Since this is a pre-developed solution
# we'll be using SageMaker mode.

# %% [markdown]
# Up next, we configure our SKLearn estimator. We will use it to coordinate
# model training and deployment. We reference our custom container (see
# `image_name`) and our custom code (see `entry_point` and `dependencies`).
# At this stage, we also reference the instance type (and instance count)
# that will be used during training, and the hyperparmeters we wish to use.
# And lastly we set the `output_path` for trained model artifacts and
# `code_location` for a snapshot of the training script that was used.
#
# **Note**: when customizing the solution, you can enable enhanced logging
# by setting the `container_log_level=logging.DEBUG` on the `SKLearn`
# estimator object (after `import logging`).

# %%
hyperparameters = {
    "tree-n-estimators": 42,
    "tree-max-depth": 2,
    "tree-min-child-samples": 1,
    "tree-boosting-type": "dart"
}

current_folder = utils.get_current_folder(globals())
estimator = SKLearn(
    image_uri=config.ECR_IMAGE,
    entry_point='entry_point.py',
    source_dir=str(Path(current_folder, '../containers/model/src').resolve()),
    dependencies=[str(Path(current_folder, '../package/package').resolve())],
    hyperparameters=hyperparameters,
    role=config.IAM_ROLE,
    instance_count=1,
    instance_type='ml.c5.xlarge',
    output_path='s3://' + str(Path(config.S3_BUCKET, config.OUTPUTS_S3_PREFIX)),
    code_location='s3://' + str(Path(config.S3_BUCKET, config.OUTPUTS_S3_PREFIX)),
    base_job_name=config.SOLUTION_PREFIX,
    tags=[{'Key': config.TAG_KEY, 'Value': config.SOLUTION_PREFIX}]
)

# %% [markdown]
# With our estimator now initialized, we can start the Amazon SageMaker
# training job. Since our entry point script expects a number of data
# channels to be defined, we can provide them when calling `fit`. When
# referencing `s3://` folders, the contents of these folders will be
# automatically downloaded from Amazon S3 before the entry point script is
# run. When using local mode, it's possible to avoid this data transfer and
# reference local folder using the `file://` prefix instead: e.g.
# `{'schemas': 'file://' + str(schema_folder)}`
#
# You can expect this step to take approximately 5 minutes.

# %%
estimator.fit({
    'schemas': 's3://' + str(Path(config.S3_BUCKET, config.SCHEMAS_S3_PREFIX)),
    'data_train': 's3://' + str(Path(config.S3_BUCKET, config.DATASETS_S3_PREFIX, 'data_train')),
    'label_train': 's3://' + str(Path(config.S3_BUCKET, config.DATASETS_S3_PREFIX, 'label_train')),
    'data_test': 's3://' + str(Path(config.S3_BUCKET, config.DATASETS_S3_PREFIX, 'data_test')),
    'label_test': 's3://' + str(Path(config.S3_BUCKET, config.DATASETS_S3_PREFIX, 'label_test'))
})
# Out:
# 2021-09-29 05:48:43 Starting - Starting the training job...
# 2021-09-29 05:49:06 Starting - Launching requested ML instancesProfilerReport-1632894522: InProgress
# ......
# 2021-09-29 05:50:06 Starting - Preparing the instances for training......
# 2021-09-29 05:51:07 Downloading - Downloading input data...
# 2021-09-29 05:51:27 Training - Downloading the training image......
# 2021-09-29 05:52:43 Uploading - Uploading generated training model
# 2021-09-29 05:52:43 Completed - Training job completed
# 2021-09-29 05:52:29,918 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-09-29 05:52:29,920 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-09-29 05:52:29,929 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-09-29 05:52:30,232 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-09-29 05:52:33,262 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-09-29 05:52:33,273 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-09-29 05:52:33,283 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "data_test": "/opt/ml/input/data/data_test",
#         "label_train": "/opt/ml/input/data/label_train",
#         "label_test": "/opt/ml/input/data/label_test",
#         "data_train": "/opt/ml/input/data/data_train",
#         "schemas": "/opt/ml/input/data/schemas"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "tree-min-child-samples": 1,
#         "tree-max-depth": 2,
#         "tree-boosting-type": "dart",
#         "tree-n-estimators": 42
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "data_test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "label_train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "label_test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "data_train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "schemas": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-soln-ecd-js-51p2dp-2021-09-29-05-48-42-978",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-soln-ecd-js-51p2dp-us-east-1-396548483691/outputs/sagemaker-soln-ecd-js-51p2dp-2021-09-29-05-48-42-978/source/sourcedir.tar.gz",
#     "module_name": "entry_point",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "entry_point.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"tree-boosting-type":"dart","tree-max-depth":2,"tree-min-child-samples":1,"tree-n-estimators":42}
# SM_USER_ENTRY_POINT=entry_point.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"data_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"data_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"label_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"label_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"schemas":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["data_test","data_train","label_test","label_train","schemas"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=entry_point
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-soln-ecd-js-51p2dp-us-east-1-396548483691/outputs/sagemaker-soln-ecd-js-51p2dp-2021-09-29-05-48-42-978/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"data_test":"/opt/ml/input/data/data_test","data_train":"/opt/ml/input/data/data_train","label_test":"/opt/ml/input/data/label_test","label_train":"/opt/ml/input/data/label_train","schemas":"/opt/ml/input/data/schemas"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"tree-boosting-type":"dart","tree-max-depth":2,"tree-min-child-samples":1,"tree-n-estimators":42},"input_config_dir":"/opt/ml/input/config","input_data_config":{"data_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"data_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"label_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"label_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"schemas":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-soln-ecd-js-51p2dp-2021-09-29-05-48-42-978","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-soln-ecd-js-51p2dp-us-east-1-396548483691/outputs/sagemaker-soln-ecd-js-51p2dp-2021-09-29-05-48-42-978/source/sourcedir.tar.gz","module_name":"entry_point","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"entry_point.py"}
# SM_USER_ARGS=["--tree-boosting-type","dart","--tree-max-depth","2","--tree-min-child-samples","1","--tree-n-estimators","42"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_DATA_TEST=/opt/ml/input/data/data_test
# SM_CHANNEL_LABEL_TRAIN=/opt/ml/input/data/label_train
# SM_CHANNEL_LABEL_TEST=/opt/ml/input/data/label_test
# SM_CHANNEL_DATA_TRAIN=/opt/ml/input/data/data_train
# SM_CHANNEL_SCHEMAS=/opt/ml/input/data/schemas
# SM_HP_TREE-MIN-CHILD-SAMPLES=1
# SM_HP_TREE-MAX-DEPTH=2
# SM_HP_TREE-BOOSTING-TYPE=dart
# SM_HP_TREE-N-ESTIMATORS=42
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python entry_point.py --tree-boosting-type dart --tree-max-depth 2 --tree-min-child-samples 1 --tree-n-estimators 42
#
#
# train_auc_cv: 0.73538 (+/- 0.06974)
# train_auc: 0.82914
# test_auc: 0.82909
# 2021-09-29 05:52:34,642 sagemaker-containers INFO     Reporting training SUCCESS
# Training seconds: 99
# Billable seconds: 99

# %% [markdown]
# Our Amazon SageMaker training job has now completed, and we should have a
# number of trained model artifacts that can be deployed and used for
# explanations.

# %% [markdown]
# ## Customization
#
# We have provided an example of model training above, so that we have a
# trained model to explain, but our solution is customizable if you have
# your own models. You can choose to retrain your models on Amazon
# SageMaker or train your models is some other way of your choosing.
#
# When re-training models on Amazon SageMaker you should modify the
# training script found at `./package/sagemaker/estimator_fns.py`. You
# should modify the `train_fn` function as required and change any of the
# other training functions (found in `./package/machine_learning` for
# example). You may need to modify the dependencies too depending on you
# model and these can be adjusted in `./containers/model/requirements.txt`.
#
# When bringing your own trained model, you will need to upload all of the
# model assets to Amazon S3 (in the solution bucket): e.g. trained
# preprocessors, model weights and feature schemas (i.e. data schema after
# feature engineering). Amazon SageMaker expects all of these model assets
# to be packages up as a `model.tar.gz`.

# %% [markdown]
# ## Next Stage
#
# Up next we'll deploy the model explainer to a HTTP endpoint using Amazon
# SageMaker and visualize the explanations.
#
# [Click here to continue.](./3_endpoint.ipynb)
