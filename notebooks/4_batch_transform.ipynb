# %% [markdown]
# # Batch Transform for Explanations
#
# In this notebook, we'll use Amazon SageMaker Batch Transform to obtain
# explanations for our complete dataset.
#
# **Note**: When running this notebook on SageMaker Studio, you should make
# sure the 'SageMaker JumpStart Data Science 1.0' image/kernel is used. You
# can run all cells or step through them one at a time.
#
# <p align="center">
#   <img src="https://github.com/awslabs/sagemaker-explaining-credit-decisions/raw/master/docs/architecture_diagrams/stage_4.png" width="1000px">
# </p>

# %% [markdown]
# We then import a variety of packages that will be used throughout
# the notebook. One of the most important packages used throughout this
# solution is the Amazon SageMaker Python SDK (i.e. `import sagemaker`). We
# also import modules from our own custom package that can be found at
# `./package`.

# %%
import boto3
from pathlib import Path
import sagemaker
from sagemaker.transformer import Transformer
import sys

sys.path.insert(0, '../package')
from package import config, utils

# %% [markdown]
# Up next, we define the current folder, a sagemaker session and a
# sagemaker client (from `boto3`).

# %%
current_folder = utils.get_current_folder(globals())
sagemaker_session = sagemaker.Session()
sagemaker_client = boto3.client('sagemaker')

# %% [markdown]
# We define a function below to retrieve the same model that was created in
# last stage. Model refers to the package of model assets and deployment
# code. We could have created another model here (using the same model data
# from the training stage) but let's use the same model to avoid
# duplication.

# %%
def get_latest_model(name_contains):
    paginator = sagemaker_client.get_paginator('list_models')
    try:
        for page in paginator.paginate(NameContains=name_contains):
            models = page['Models']
            if len(models):
                return models[0]['ModelName']
    except:
        raise ValueError("Couldn't find any models with '{}' in name.".format(name_contains))

# %%
latest_model = get_latest_model(config.SOLUTION_PREFIX)
print("latest model: {}".format(latest_model))
job_name = latest_model
# Out:
# latest model: sagemaker-soln-ecd-js-51p2dp-explainer

# %% [markdown]
# Unlike the last stage, where we deployed an endpoint, we define a
# `Transformer` to perform the batch computation. We specify the instance
# type that should be used for the computation (i.e. `ml.c5.xlarge`) and a
# number of other parameters. `strategy='SingleRecord'` means that records
# will be processed by the explainer one at a time. And `output_path`
# defines where the Batch Transform output should be saved.

# %%
batch_explainer = Transformer(
    model_name=latest_model,
    instance_count=1,
    instance_type='ml.c5.xlarge',
    strategy='SingleRecord',
    assemble_with='Line',
    output_path='s3://' + str(Path(config.S3_BUCKET, 'explanations', job_name)) + '/',
    accept='application/json',
    base_transform_job_name=config.SOLUTION_PREFIX,
    sagemaker_session=sagemaker_session,
    tags=[{'Key': config.TAG_KEY, 'Value': config.SOLUTION_PREFIX}]
)

# %% [markdown]
# We haven't yet started the Batch Transform Job. Calling `.transform` does
# that below. We also specify the `content_type` at this stage, which gives
# us control over what type of entities we want to return from the
# explainer. As an example, we have requested SHAP interaction values
# during this batch job.

# %%
entities = [
    'data',
    'features',
    'prediction',
    'explanation_shap_values',
    'explanation_shap_interaction_values'
]
batch_explainer.transform(
    data='s3://' + str(Path(config.S3_BUCKET, config.DATASETS_S3_PREFIX, 'data_test')) + '/',
    content_type="application/json; entities={}".format(",".join(entities)),
    split_type='Line',
    wait=True
)
# Out:
# .........................Processing /opt/ml/code
# Building wheels for collected packages: entry-point
#   Building wheel for entry-point (setup.py): started
#   Building wheel for entry-point (setup.py): finished with status 'done'
#   Created wheel for entry-point: filename=entry_point-1.0.0-py2.py3-none-any.whl size=38534 sha256=fa47e97269bafac1701f66e3ba3d230d53248c8ec1ca60e4bb37443d5f39349a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ywja_ty5/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built entry-point
# Installing collected packages: entry-point
# Successfully installed entry-point-1.0.0
# [2021-09-29 06:34:34 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-09-29 06:34:34 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-09-29 06:34:34 +0000] [36] [INFO] Using worker: gevent
# [2021-09-29 06:34:34 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-09-29 06:34:34 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-09-29 06:34:34 +0000] [41] [INFO] Booting worker with pid: 41
# [2021-09-29 06:34:34 +0000] [42] [INFO] Booting worker with pid: 42
# 2021-09-29 06:34:36,980 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 169.254.255.130 - - [29/Sep/2021:06:34:37 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-09-29 06:34:37,526 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19000 "-" "Go-http-client/1.1"
# 2021-09-29 06:34:38,167 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19036 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:38 +0000] "POST /invocations HTTP/1.1" 200 19007 "-" "Go-http-client/1.1"
# 2021-09-29 06:34:38,794 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18998 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18997 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18998 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18997 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18970 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19007 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19039 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19002 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19037 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18988 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19032 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19026 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18970 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19007 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19039 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19002 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19037 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 18988 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19032 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:39 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19026 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 2021-09-29T06:34:38.045:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=SINGLE_RECORD
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19048 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19048 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19042 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19036 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19005 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19005 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19007 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19050 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19042 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19036 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19005 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19005 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19007 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19050 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19039 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:40 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19039 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19026 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18992 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19049 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18998 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18997 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19003 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19026 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19024 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19012 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18992 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19016 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19049 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18998 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18997 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19033 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19003 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19046 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18984 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19047 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19040 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19044 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19040 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19046 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18984 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19047 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19040 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19023 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19019 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19025 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:41 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19041 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19044 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19040 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19017 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19046 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19043 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19044 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19037 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19036 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19032 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18992 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19000 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19046 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19015 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19043 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19027 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19028 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19011 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19044 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19037 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19034 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19036 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19035 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19030 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19038 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19029 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19010 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19032 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19008 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19031 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19021 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19018 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18992 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19006 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19009 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19000 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19020 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19000 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19003 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18987 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18979 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19004 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18975 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18964 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18981 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18974 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19014 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19000 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19003 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18987 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18979 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19022 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19004 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18975 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18964 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 18996 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:42 +0000] "POST /invocations HTTP/1.1" 200 19001 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 19013 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18981 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18974 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18993 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18982 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [29/Sep/2021:06:34:43 +0000] "POST /invocations HTTP/1.1" 200 18982 "-" "Go-http-client/1.1"

# %% [markdown]
# After the Batch Transform Job has completed successfully, we will have a
# complete set of explanations sitting in the Amazon S3 bucket.

# %% [markdown]
# ## Next Stage
#
# Up next we'll wrap things up and discuss how to clean up the solution.
#
# [Click here to continue.](./5_conclusion.ipynb)
